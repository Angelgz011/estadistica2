# %% [markdown]
# <a href="https://colab.research.google.com/github/Angelgz011/estadistica2/blob/main/eii_u2_02_22150429.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Angelgz011/estadistica2/refs/heads/main/StudentPerformanceFactors.csv")
df.dropna(inplace=True)

df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                            No            7               73
# 1                            No            8               59
# 2                           Yes            7               91
# 3                           Yes            8               98
# 4                           Yes            6               65
# ...                         ...          ...              ...
# 6602                         No            7               76
# 6603                         No            8               81
# 6604                        Yes            6               65
# 6605                        Yes            6               91
# 6606                        Yes            9               94
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 0                 Low             Yes                  0           Low
# 1                 Low             Yes                  2        Medium
# 2              Medium             Yes                  2        Medium
# 3              Medium             Yes                  1        Medium
# 4              Medium             Yes                  3        Medium
# ...               ...             ...                ...           ...
# 6602           Medium             Yes                  1          High
# 6603           Medium             Yes                  3           Low
# 6604              Low             Yes                  3           Low
# 6605             High             Yes                  2           Low
# 6606           Medium             Yes                  0        Medium
#
#      Teacher_Quality School_Type Peer_Influence  Physical_Activity  \
# 0             Medium      Public       Positive                  3
# 1             Medium      Public       Negative                  4
# 2             Medium      Public        Neutral                  4
# 3             Medium      Public       Negative                  4
# 4               High      Public        Neutral                  4
# ...              ...         ...            ...                ...
# 6602          Medium      Public       Positive                  2
# 6603            High      Public       Positive                  2
# 6604          Medium      Public       Negative                  2
# 6605          Medium     Private       Positive                  3
# 6606          Medium      Public       Positive                  4
#
#      Learning_Disabilities Parental_Education_Level Distance_from_Home  \
# 0                       No              High School               Near
# 1                       No                  College           Moderate
# 2                       No             Postgraduate               Near
# 3                       No              High School           Moderate
# 4                       No                  College               Near
# ...                    ...                      ...                ...
# 6602                    No              High School               Near
# 6603                    No              High School               Near
# 6604                    No             Postgraduate               Near
# 6605                    No              High School                Far
# 6606                    No             Postgraduate               Near
#
#       Gender  Exam_Score
# 0       Male          67
# 1     Female          61
# 2       Male          74
# 3       Male          71
# 4     Female          70
# ...      ...         ...
# 6602  Female          68
# 6603  Female          69
# 6604  Female          68
# 6605  Female          68
# 6606    Male          64
#
# [6378 rows x 20 columns]

# %%
#HISOGRAMA HORAS ESTUDIADAS
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Hours_Studied'], kde=True, color='skyblue')
plt.xlabel('Horas de estudio por semana')
plt.ylabel('Frecuencia')
plt.title('Distribución de horas de estudio')


plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

plt.show()

# %%
#HISOGRAMA Asistencia
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Attendance'], kde=True, color='skyblue')
plt.xlabel('Porcentaje de asistencias')
plt.ylabel('Frecuencia')
plt.title('Distribución de asistencias')


plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

plt.show()

# %%
#Prueba ANOVA para ParentaL_Involvemet
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols('Exam_Score ~ C(Parental_Involvement)',data = df ).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#H0: No hay diferencia entre grupos.
# Out:
#                              df        sum_sq      mean_sq          F  \
# C(Parental_Involvement)     2.0   2405.587354  1202.793677  80.462228
# Residual                 6375.0  95297.009071    14.948550        NaN
#
#                                PR(>F)
# C(Parental_Involvement)  3.086485e-35
# Residual                          NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt
nivel_de_significancia = 0.05
tukey = pairwise_tukeyhsd(endog = df['Exam_Score'], groups = df['Parental_Involvement'], alpha = nivel_de_significancia)
tukey.plot_simultaneous(ylabel = 'Niveles de medición', xlabel = 'Unidades de la variable')
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.title('')
print(tukey)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#   High    Low  -1.7334   0.0 -2.0626 -1.4042   True
#   High Medium   -0.999   0.0 -1.2636 -0.7344   True
#    Low Medium   0.7344   0.0  0.4363  1.0326   True
# ---------------------------------------------------

# %%
niveles = {'Low': 0, 'Medium': 50, 'High': 100}
df['Parental_Involvement'] = df['Parental_Involvement'].map(niveles)

# %%
#Prueba ANOVA para Access_to_Resources
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols('Exam_Score ~ C(Access_to_Resources)',data = df ).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#H0: No hay diferencia entre grupos.
#Se rechaza la Hipotesis nula
# Out:
#                             df        sum_sq      mean_sq         F  \
# C(Access_to_Resources)     2.0   2752.911147  1376.455574  92.41636
# Residual                6375.0  94949.685278    14.894068       NaN
#
#                               PR(>F)
# C(Access_to_Resources)  2.722170e-40
# Residual                         NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt
nivel_de_significancia = 0.05
tukey = pairwise_tukeyhsd(endog = df['Exam_Score'], groups = df['Access_to_Resources'], alpha = nivel_de_significancia)
tukey.plot_simultaneous(ylabel = 'Niveles de medición', xlabel = 'Unidades de la variable')
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.title('')
print(tukey)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#   High    Low  -1.8795   0.0 -2.2071 -1.5518   True
#   High Medium  -0.9468   0.0 -1.2088 -0.6848   True
#    Low Medium   0.9327   0.0   0.633  1.2323   True
# ---------------------------------------------------

# %%
niveles = {'Low': 0, 'Medium': 50, 'High': 100}
df['Access_to_Resources'] = df['Access_to_Resources'].map(niveles)

# %%
#Prueba ANOVA para Access_to_Resources
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols('Exam_Score ~ C(Extracurricular_Activities)',data = df ).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#H0: No hay diferencia entre grupos.
# Out:
#                                    df        sum_sq     mean_sq          F  \
# C(Extracurricular_Activities)     1.0    388.552812  388.552812  25.457916
# Residual                       6376.0  97314.043614   15.262554        NaN
#
#                                      PR(>F)
# C(Extracurricular_Activities)  4.646554e-07
# Residual                                NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt
nivel_de_significancia = 0.05
tukey = pairwise_tukeyhsd(endog = df['Exam_Score'], groups = df['Extracurricular_Activities'], alpha = nivel_de_significancia)
tukey.plot_simultaneous(ylabel = 'Niveles de medición', xlabel = 'Unidades de la variable')
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.title('')
print(tukey)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================
# group1 group2 meandiff p-adj lower  upper  reject
# -------------------------------------------------
#     No    Yes   0.5032   0.0 0.3077 0.6987   True
# -------------------------------------------------

# %%
niveles = {'No': 0, 'Yes': 1}
df['Extracurricular_Activities'] = df['Extracurricular_Activities'].map(niveles)
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                  100
# 1                19          64                     0                   50
# 2                24          98                    50                   50
# 3                29          89                     0                   50
# 4                19          92                    50                   50
# ...             ...         ...                   ...                  ...
# 6602             25          69                   100                   50
# 6603             23          76                   100                   50
# 6604             20          90                    50                    0
# 6605             10          86                   100                  100
# 6606             15          67                    50                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                              0            7               73
# 1                              0            8               59
# 2                              1            7               91
# 3                              1            8               98
# 4                              1            6               65
# ...                          ...          ...              ...
# 6602                           0            7               76
# 6603                           0            8               81
# 6604                           1            6               65
# 6605                           1            6               91
# 6606                           1            9               94
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 0                 Low             Yes                  0           Low
# 1                 Low             Yes                  2        Medium
# 2              Medium             Yes                  2        Medium
# 3              Medium             Yes                  1        Medium
# 4              Medium             Yes                  3        Medium
# ...               ...             ...                ...           ...
# 6602           Medium             Yes                  1          High
# 6603           Medium             Yes                  3           Low
# 6604              Low             Yes                  3           Low
# 6605             High             Yes                  2           Low
# 6606           Medium             Yes                  0        Medium
#
#      Teacher_Quality School_Type Peer_Influence  Physical_Activity  \
# 0             Medium      Public       Positive                  3
# 1             Medium      Public       Negative                  4
# 2             Medium      Public        Neutral                  4
# 3             Medium      Public       Negative                  4
# 4               High      Public        Neutral                  4
# ...              ...         ...            ...                ...
# 6602          Medium      Public       Positive                  2
# 6603            High      Public       Positive                  2
# 6604          Medium      Public       Negative                  2
# 6605          Medium     Private       Positive                  3
# 6606          Medium      Public       Positive                  4
#
#      Learning_Disabilities Parental_Education_Level Distance_from_Home  \
# 0                       No              High School               Near
# 1                       No                  College           Moderate
# 2                       No             Postgraduate               Near
# 3                       No              High School           Moderate
# 4                       No                  College               Near
# ...                    ...                      ...                ...
# 6602                    No              High School               Near
# 6603                    No              High School               Near
# 6604                    No             Postgraduate               Near
# 6605                    No              High School                Far
# 6606                    No             Postgraduate               Near
#
#       Gender  Exam_Score
# 0       Male          67
# 1     Female          61
# 2       Male          74
# 3       Male          71
# 4     Female          70
# ...      ...         ...
# 6602  Female          68
# 6603  Female          69
# 6604  Female          68
# 6605  Female          68
# 6606    Male          64
#
# [6378 rows x 20 columns]

# %%
#HISOGRAMA Horas de sueño
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Sleep_Hours'], kde=True, color='skyblue')
plt.xlabel('Horas de Sueño')
plt.ylabel('Frecuencia')
plt.title('Distribución de horas de sueño')


plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

plt.show()

# %%
#HISOGRAMA PREVIOUS SCORES
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Previous_Scores'], kde=True, color='skyblue')
plt.xlabel('Notas pasadas')
plt.ylabel('Frecuencia')
plt.title('Distribución de Previous Scores')


plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

plt.show()

# %%
#Prueba ANOVA para Access_to_Resources
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols('Exam_Score ~ C(Motivation_Level)',data = df ).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#H0: No hay diferencia entre grupos.
#Se rechaza la hipotesis nula
# Out:
#                          df        sum_sq     mean_sq          F        PR(>F)
# C(Motivation_Level)     2.0    776.488813  388.244407  25.535515  9.000204e-12
# Residual             6375.0  96926.107612   15.204095        NaN           NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt
nivel_de_significancia = 0.05
tukey = pairwise_tukeyhsd(endog = df['Exam_Score'], groups = df['Motivation_Level'], alpha = nivel_de_significancia)
tukey.plot_simultaneous(ylabel = 'Niveles de medición', xlabel = 'Unidades de la variable')
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.title('')
print(tukey)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#   High    Low  -0.9794    0.0 -1.3115 -0.6474   True
#   High Medium   -0.405 0.0048 -0.7071  -0.103   True
#    Low Medium   0.5744    0.0  0.3086  0.8402   True
# ----------------------------------------------------

# %%
niveles = {'Low': 0, 'Medium': 50, 'High': 100}
df['Motivation_Level'] = df['Motivation_Level'].map(niveles)
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                  100
# 1                19          64                     0                   50
# 2                24          98                    50                   50
# 3                29          89                     0                   50
# 4                19          92                    50                   50
# ...             ...         ...                   ...                  ...
# 6602             25          69                   100                   50
# 6603             23          76                   100                   50
# 6604             20          90                    50                    0
# 6605             10          86                   100                  100
# 6606             15          67                    50                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                              0            7               73
# 1                              0            8               59
# 2                              1            7               91
# 3                              1            8               98
# 4                              1            6               65
# ...                          ...          ...              ...
# 6602                           0            7               76
# 6603                           0            8               81
# 6604                           1            6               65
# 6605                           1            6               91
# 6606                           1            9               94
#
#       Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 0                    0             Yes                  0           Low
# 1                    0             Yes                  2        Medium
# 2                   50             Yes                  2        Medium
# 3                   50             Yes                  1        Medium
# 4                   50             Yes                  3        Medium
# ...                ...             ...                ...           ...
# 6602                50             Yes                  1          High
# 6603                50             Yes                  3           Low
# 6604                 0             Yes                  3           Low
# 6605               100             Yes                  2           Low
# 6606                50             Yes                  0        Medium
#
#      Teacher_Quality School_Type Peer_Influence  Physical_Activity  \
# 0             Medium      Public       Positive                  3
# 1             Medium      Public       Negative                  4
# 2             Medium      Public        Neutral                  4
# 3             Medium      Public       Negative                  4
# 4               High      Public        Neutral                  4
# ...              ...         ...            ...                ...
# 6602          Medium      Public       Positive                  2
# 6603            High      Public       Positive                  2
# 6604          Medium      Public       Negative                  2
# 6605          Medium     Private       Positive                  3
# 6606          Medium      Public       Positive                  4
#
#      Learning_Disabilities Parental_Education_Level Distance_from_Home  \
# 0                       No              High School               Near
# 1                       No                  College           Moderate
# 2                       No             Postgraduate               Near
# 3                       No              High School           Moderate
# 4                       No                  College               Near
# ...                    ...                      ...                ...
# 6602                    No              High School               Near
# 6603                    No              High School               Near
# 6604                    No             Postgraduate               Near
# 6605                    No              High School                Far
# 6606                    No             Postgraduate               Near
#
#       Gender  Exam_Score
# 0       Male          67
# 1     Female          61
# 2       Male          74
# 3       Male          71
# 4     Female          70
# ...      ...         ...
# 6602  Female          68
# 6603  Female          69
# 6604  Female          68
# 6605  Female          68
# 6606    Male          64
#
# [6378 rows x 20 columns]

# %%
#Prueba ANOVA para Access_to_Resources
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols('Exam_Score ~ C(Internet_Access)',data = df ).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#H0: No hay diferencia entre grupos.
#Se rechaza la hipotesis nula
# Out:
#                         df        sum_sq     mean_sq          F    PR(>F)
# C(Internet_Access)     1.0    255.358422  255.358422  16.708173  0.000044
# Residual            6376.0  97447.238003   15.283444        NaN       NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt
nivel_de_significancia = 0.05
tukey = pairwise_tukeyhsd(endog = df['Exam_Score'], groups = df['Internet_Access'], alpha = nivel_de_significancia)
tukey.plot_simultaneous(ylabel = 'Niveles de medición', xlabel = 'Unidades de la variable')
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.title('')
print(tukey)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================
# group1 group2 meandiff p-adj lower  upper  reject
# -------------------------------------------------
#     No    Yes   0.7549   0.0 0.3929 1.1169   True
# -------------------------------------------------

# %%
niveles = {'Yes': 1, 'No': 0}
df['Internet_Access'] = df['Internet_Access'].map(niveles)
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                  100
# 1                19          64                     0                   50
# 2                24          98                    50                   50
# 3                29          89                     0                   50
# 4                19          92                    50                   50
# ...             ...         ...                   ...                  ...
# 6602             25          69                   100                   50
# 6603             23          76                   100                   50
# 6604             20          90                    50                    0
# 6605             10          86                   100                  100
# 6606             15          67                    50                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                              0            7               73
# 1                              0            8               59
# 2                              1            7               91
# 3                              1            8               98
# 4                              1            6               65
# ...                          ...          ...              ...
# 6602                           0            7               76
# 6603                           0            8               81
# 6604                           1            6               65
# 6605                           1            6               91
# 6606                           1            9               94
#
#       Motivation_Level  Internet_Access  Tutoring_Sessions Family_Income  \
# 0                    0                1                  0           Low
# 1                    0                1                  2        Medium
# 2                   50                1                  2        Medium
# 3                   50                1                  1        Medium
# 4                   50                1                  3        Medium
# ...                ...              ...                ...           ...
# 6602                50                1                  1          High
# 6603                50                1                  3           Low
# 6604                 0                1                  3           Low
# 6605               100                1                  2           Low
# 6606                50                1                  0        Medium
#
#      Teacher_Quality School_Type Peer_Influence  Physical_Activity  \
# 0             Medium      Public       Positive                  3
# 1             Medium      Public       Negative                  4
# 2             Medium      Public        Neutral                  4
# 3             Medium      Public       Negative                  4
# 4               High      Public        Neutral                  4
# ...              ...         ...            ...                ...
# 6602          Medium      Public       Positive                  2
# 6603            High      Public       Positive                  2
# 6604          Medium      Public       Negative                  2
# 6605          Medium     Private       Positive                  3
# 6606          Medium      Public       Positive                  4
#
#      Learning_Disabilities Parental_Education_Level Distance_from_Home  \
# 0                       No              High School               Near
# 1                       No                  College           Moderate
# 2                       No             Postgraduate               Near
# 3                       No              High School           Moderate
# 4                       No                  College               Near
# ...                    ...                      ...                ...
# 6602                    No              High School               Near
# 6603                    No              High School               Near
# 6604                    No             Postgraduate               Near
# 6605                    No              High School                Far
# 6606                    No             Postgraduate               Near
#
#       Gender  Exam_Score
# 0       Male          67
# 1     Female          61
# 2       Male          74
# 3       Male          71
# 4     Female          70
# ...      ...         ...
# 6602  Female          68
# 6603  Female          69
# 6604  Female          68
# 6605  Female          68
# 6606    Male          64
#
# [6378 rows x 20 columns]

# %%
#HISOGRAMA TUTORING SESSIONS
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Tutoring_Sessions'], kde=True, color='skyblue')
plt.xlabel('Sesiones de tutoría')
plt.ylabel('Frecuencia')
plt.title('Distribución de Sesiones de Tutoría')


plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

plt.show()

# %%
#Prueba ANOVA para Family_Income
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols('Exam_Score ~ C(Family_Income)',data = df ).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#H0: No hay diferencia entre grupos.
#Se rechaza la hipotesis nula.
# Out:
#                       df        sum_sq     mean_sq          F        PR(>F)
# C(Family_Income)     2.0    874.339934  437.169967  28.782492  3.597672e-13
# Residual          6375.0  96828.256491   15.188746        NaN           NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt
nivel_de_significancia = 0.05
tukey = pairwise_tukeyhsd(endog = df['Exam_Score'], groups = df['Family_Income'], alpha = nivel_de_significancia)
tukey.plot_simultaneous(ylabel = 'Niveles de medición', xlabel = 'Unidades de la variable')
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.title('')
print(tukey)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#   High    Low  -0.9882    0.0 -1.3048 -0.6717   True
#   High Medium  -0.4705 0.0015 -0.7873 -0.1536   True
#    Low Medium   0.5178    0.0  0.2631  0.7725   True
# ----------------------------------------------------

# %%
niveles = {'Low': 0, 'Medium': 50, 'High': 100}
df['Family_Income'] = df['Family_Income'].map(niveles)
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                  100
# 1                19          64                     0                   50
# 2                24          98                    50                   50
# 3                29          89                     0                   50
# 4                19          92                    50                   50
# ...             ...         ...                   ...                  ...
# 6602             25          69                   100                   50
# 6603             23          76                   100                   50
# 6604             20          90                    50                    0
# 6605             10          86                   100                  100
# 6606             15          67                    50                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                              0            7               73
# 1                              0            8               59
# 2                              1            7               91
# 3                              1            8               98
# 4                              1            6               65
# ...                          ...          ...              ...
# 6602                           0            7               76
# 6603                           0            8               81
# 6604                           1            6               65
# 6605                           1            6               91
# 6606                           1            9               94
#
#       Motivation_Level  Internet_Access  Tutoring_Sessions  Family_Income  \
# 0                    0                1                  0              0
# 1                    0                1                  2             50
# 2                   50                1                  2             50
# 3                   50                1                  1             50
# 4                   50                1                  3             50
# ...                ...              ...                ...            ...
# 6602                50                1                  1            100
# 6603                50                1                  3              0
# 6604                 0                1                  3              0
# 6605               100                1                  2              0
# 6606                50                1                  0             50
#
#      Teacher_Quality School_Type Peer_Influence  Physical_Activity  \
# 0             Medium      Public       Positive                  3
# 1             Medium      Public       Negative                  4
# 2             Medium      Public        Neutral                  4
# 3             Medium      Public       Negative                  4
# 4               High      Public        Neutral                  4
# ...              ...         ...            ...                ...
# 6602          Medium      Public       Positive                  2
# 6603            High      Public       Positive                  2
# 6604          Medium      Public       Negative                  2
# 6605          Medium     Private       Positive                  3
# 6606          Medium      Public       Positive                  4
#
#      Learning_Disabilities Parental_Education_Level Distance_from_Home  \
# 0                       No              High School               Near
# 1                       No                  College           Moderate
# 2                       No             Postgraduate               Near
# 3                       No              High School           Moderate
# 4                       No                  College               Near
# ...                    ...                      ...                ...
# 6602                    No              High School               Near
# 6603                    No              High School               Near
# 6604                    No             Postgraduate               Near
# 6605                    No              High School                Far
# 6606                    No             Postgraduate               Near
#
#       Gender  Exam_Score
# 0       Male          67
# 1     Female          61
# 2       Male          74
# 3       Male          71
# 4     Female          70
# ...      ...         ...
# 6602  Female          68
# 6603  Female          69
# 6604  Female          68
# 6605  Female          68
# 6606    Male          64
#
# [6378 rows x 20 columns]

# %%
#Prueba ANOVA para Teacher_Quality
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols('Exam_Score ~ C(Teacher_Quality)',data = df ).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#H0: No hay diferencia entre grupos.
#Se rechaza la hipotesis nula.
# Out:
#                         df        sum_sq     mean_sq         F        PR(>F)
# C(Teacher_Quality)     2.0    566.739816  283.369908  18.59749  8.844704e-09
# Residual            6375.0  97135.856609   15.236997       NaN           NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt
nivel_de_significancia = 0.05
tukey = pairwise_tukeyhsd(endog = df['Exam_Score'], groups = df['Teacher_Quality'], alpha = nivel_de_significancia)
tukey.plot_simultaneous(ylabel = 'Niveles de medición', xlabel = 'Unidades de la variable')
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.title('')
print(tukey)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#   High    Low   -0.906    0.0 -1.3224 -0.4896   True
#   High Medium  -0.5632    0.0 -0.8198 -0.3066   True
#    Low Medium   0.3428 0.0971 -0.0462  0.7318  False
# ----------------------------------------------------

# %%
niveles = {'Low': 0, 'Medium': 0, 'High': 100}
df['Teacher_Quality'] = df['Teacher_Quality'].map(niveles)
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                  100
# 1                19          64                     0                   50
# 2                24          98                    50                   50
# 3                29          89                     0                   50
# 4                19          92                    50                   50
# ...             ...         ...                   ...                  ...
# 6602             25          69                   100                   50
# 6603             23          76                   100                   50
# 6604             20          90                    50                    0
# 6605             10          86                   100                  100
# 6606             15          67                    50                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                              0            7               73
# 1                              0            8               59
# 2                              1            7               91
# 3                              1            8               98
# 4                              1            6               65
# ...                          ...          ...              ...
# 6602                           0            7               76
# 6603                           0            8               81
# 6604                           1            6               65
# 6605                           1            6               91
# 6606                           1            9               94
#
#       Motivation_Level  Internet_Access  Tutoring_Sessions  Family_Income  \
# 0                    0                1                  0              0
# 1                    0                1                  2             50
# 2                   50                1                  2             50
# 3                   50                1                  1             50
# 4                   50                1                  3             50
# ...                ...              ...                ...            ...
# 6602                50                1                  1            100
# 6603                50                1                  3              0
# 6604                 0                1                  3              0
# 6605               100                1                  2              0
# 6606                50                1                  0             50
#
#       Teacher_Quality School_Type Peer_Influence  Physical_Activity  \
# 0                   0      Public       Positive                  3
# 1                   0      Public       Negative                  4
# 2                   0      Public        Neutral                  4
# 3                   0      Public       Negative                  4
# 4                 100      Public        Neutral                  4
# ...               ...         ...            ...                ...
# 6602                0      Public       Positive                  2
# 6603              100      Public       Positive                  2
# 6604                0      Public       Negative                  2
# 6605                0     Private       Positive                  3
# 6606                0      Public       Positive                  4
#
#      Learning_Disabilities Parental_Education_Level Distance_from_Home  \
# 0                       No              High School               Near
# 1                       No                  College           Moderate
# 2                       No             Postgraduate               Near
# 3                       No              High School           Moderate
# 4                       No                  College               Near
# ...                    ...                      ...                ...
# 6602                    No              High School               Near
# 6603                    No              High School               Near
# 6604                    No             Postgraduate               Near
# 6605                    No              High School                Far
# 6606                    No             Postgraduate               Near
#
#       Gender  Exam_Score
# 0       Male          67
# 1     Female          61
# 2       Male          74
# 3       Male          71
# 4     Female          70
# ...      ...         ...
# 6602  Female          68
# 6603  Female          69
# 6604  Female          68
# 6605  Female          68
# 6606    Male          64
#
# [6378 rows x 20 columns]

# %%
#Prueba ANOVA para School_Type
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols('Exam_Score ~ C(School_Type)',data = df ).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#H0: No hay diferencia entre grupos.
#Se rechaza la hipotesis nula.
# Out:
#                     df        sum_sq    mean_sq         F    PR(>F)
# C(School_Type)     1.0     11.540237  11.540237  0.753196  0.385499
# Residual        6376.0  97691.056188  15.321684       NaN       NaN

# %%
df.drop(columns = ['School_Type'], inplace = True)

# %%
 #Prueba ANOVA para Peer_Influence
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols('Exam_Score ~ C(Peer_Influence)',data = df ).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#H0: No hay diferencia entre grupos.
# Out:
#                        df        sum_sq     mean_sq          F        PR(>F)
# C(Peer_Influence)     2.0    976.526155  488.263077  32.180333  1.242613e-14
# Residual           6375.0  96726.070271   15.172717        NaN           NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt
nivel_de_significancia = 0.05
tukey = pairwise_tukeyhsd(endog = df['Exam_Score'], groups = df['Peer_Influence'], alpha = nivel_de_significancia)
tukey.plot_simultaneous(ylabel = 'Niveles de medición', xlabel = 'Unidades de la variable')
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.title('')
print(tukey)
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ======================================================
#  group1   group2  meandiff p-adj  lower  upper  reject
# ------------------------------------------------------
# Negative  Neutral   0.6329    0.0 0.3229 0.9429   True
# Negative Positive   1.0538    0.0  0.745 1.3626   True
#  Neutral Positive   0.4209 0.0004 0.1638 0.6779   True
# ------------------------------------------------------

# %%
niveles = {'Negative': -1, 'Neutral': 0, 'Positive': 1}
df['Peer_Influence'] = df['Peer_Influence'].map(niveles)
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                  100
# 1                19          64                     0                   50
# 2                24          98                    50                   50
# 3                29          89                     0                   50
# 4                19          92                    50                   50
# ...             ...         ...                   ...                  ...
# 6602             25          69                   100                   50
# 6603             23          76                   100                   50
# 6604             20          90                    50                    0
# 6605             10          86                   100                  100
# 6606             15          67                    50                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                              0            7               73
# 1                              0            8               59
# 2                              1            7               91
# 3                              1            8               98
# 4                              1            6               65
# ...                          ...          ...              ...
# 6602                           0            7               76
# 6603                           0            8               81
# 6604                           1            6               65
# 6605                           1            6               91
# 6606                           1            9               94
#
#       Motivation_Level  Internet_Access  Tutoring_Sessions  Family_Income  \
# 0                    0                1                  0              0
# 1                    0                1                  2             50
# 2                   50                1                  2             50
# 3                   50                1                  1             50
# 4                   50                1                  3             50
# ...                ...              ...                ...            ...
# 6602                50                1                  1            100
# 6603                50                1                  3              0
# 6604                 0                1                  3              0
# 6605               100                1                  2              0
# 6606                50                1                  0             50
#
#       Teacher_Quality  Peer_Influence  Physical_Activity  \
# 0                   0               1                  3
# 1                   0              -1                  4
# 2                   0               0                  4
# 3                   0              -1                  4
# 4                 100               0                  4
# ...               ...             ...                ...
# 6602                0               1                  2
# 6603              100               1                  2
# 6604                0              -1                  2
# 6605                0               1                  3
# 6606                0               1                  4
#
#      Learning_Disabilities Parental_Education_Level Distance_from_Home  \
# 0                       No              High School               Near
# 1                       No                  College           Moderate
# 2                       No             Postgraduate               Near
# 3                       No              High School           Moderate
# 4                       No                  College               Near
# ...                    ...                      ...                ...
# 6602                    No              High School               Near
# 6603                    No              High School               Near
# 6604                    No             Postgraduate               Near
# 6605                    No              High School                Far
# 6606                    No             Postgraduate               Near
#
#       Gender  Exam_Score
# 0       Male          67
# 1     Female          61
# 2       Male          74
# 3       Male          71
# 4     Female          70
# ...      ...         ...
# 6602  Female          68
# 6603  Female          69
# 6604  Female          68
# 6605  Female          68
# 6606    Male          64
#
# [6378 rows x 19 columns]

# %%
#HISOGRAMA Physical_Activity
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Physical_Activity'], kde=True, color='skyblue')
plt.xlabel('Actividad fisica')
plt.ylabel('Frecuencia')
plt.title('Distribución de la Actividad Fisica')


plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

plt.show()

# %%
 #Prueba ANOVA para Learning_Disabilities
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols('Exam_Score ~ C(Learning_Disabilities)',data = df ).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#H0: No hay diferencia entre grupos.
# Out:
#                               df        sum_sq     mean_sq          F  \
# C(Learning_Disabilities)     1.0    687.937066  687.937066  45.212618
# Residual                  6376.0  97014.659360   15.215599        NaN
#
#                                 PR(>F)
# C(Learning_Disabilities)  1.921126e-11
# Residual                           NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt
nivel_de_significancia = 0.05
tukey = pairwise_tukeyhsd(endog = df['Exam_Score'], groups = df['Learning_Disabilities'], alpha = nivel_de_significancia)
tukey.plot_simultaneous(ylabel = 'Niveles de medición', xlabel = 'Unidades de la variable')
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.title('')
print(tukey)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#     No    Yes  -1.0725   0.0 -1.3852 -0.7598   True
# ---------------------------------------------------

# %%
niveles = {'No': 0, 'Yes': 1}
df['Learning_Disabilities'] = df['Learning_Disabilities'].map(niveles)
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                  100
# 1                19          64                     0                   50
# 2                24          98                    50                   50
# 3                29          89                     0                   50
# 4                19          92                    50                   50
# ...             ...         ...                   ...                  ...
# 6602             25          69                   100                   50
# 6603             23          76                   100                   50
# 6604             20          90                    50                    0
# 6605             10          86                   100                  100
# 6606             15          67                    50                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                              0            7               73
# 1                              0            8               59
# 2                              1            7               91
# 3                              1            8               98
# 4                              1            6               65
# ...                          ...          ...              ...
# 6602                           0            7               76
# 6603                           0            8               81
# 6604                           1            6               65
# 6605                           1            6               91
# 6606                           1            9               94
#
#       Motivation_Level  Internet_Access  Tutoring_Sessions  Family_Income  \
# 0                    0                1                  0              0
# 1                    0                1                  2             50
# 2                   50                1                  2             50
# 3                   50                1                  1             50
# 4                   50                1                  3             50
# ...                ...              ...                ...            ...
# 6602                50                1                  1            100
# 6603                50                1                  3              0
# 6604                 0                1                  3              0
# 6605               100                1                  2              0
# 6606                50                1                  0             50
#
#       Teacher_Quality  Peer_Influence  Physical_Activity  \
# 0                   0               1                  3
# 1                   0              -1                  4
# 2                   0               0                  4
# 3                   0              -1                  4
# 4                 100               0                  4
# ...               ...             ...                ...
# 6602                0               1                  2
# 6603              100               1                  2
# 6604                0              -1                  2
# 6605                0               1                  3
# 6606                0               1                  4
#
#       Learning_Disabilities Parental_Education_Level Distance_from_Home  \
# 0                         0              High School               Near
# 1                         0                  College           Moderate
# 2                         0             Postgraduate               Near
# 3                         0              High School           Moderate
# 4                         0                  College               Near
# ...                     ...                      ...                ...
# 6602                      0              High School               Near
# 6603                      0              High School               Near
# 6604                      0             Postgraduate               Near
# 6605                      0              High School                Far
# 6606                      0             Postgraduate               Near
#
#       Gender  Exam_Score
# 0       Male          67
# 1     Female          61
# 2       Male          74
# 3       Male          71
# 4     Female          70
# ...      ...         ...
# 6602  Female          68
# 6603  Female          69
# 6604  Female          68
# 6605  Female          68
# 6606    Male          64
#
# [6378 rows x 19 columns]

# %%
 #Prueba ANOVA para Parental_Education_Level
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols('Exam_Score ~ C(Parental_Education_Level)',data = df ).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#H0: No hay diferencia entre grupos.
# Out:
#                                  df        sum_sq     mean_sq          F  \
# C(Parental_Education_Level)     2.0   1089.555877  544.777939  35.947108
# Residual                     6375.0  96613.040548   15.154987        NaN
#
#                                    PR(>F)
# C(Parental_Education_Level)  2.990498e-16
# Residual                              NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt
nivel_de_significancia = 0.05
tukey = pairwise_tukeyhsd(endog = df['Exam_Score'], groups = df['Parental_Education_Level'], alpha = nivel_de_significancia)
tukey.plot_simultaneous(ylabel = 'Niveles de medición', xlabel = 'Unidades de la variable')
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.title('')
print(tukey)
# Out:
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1      group2    meandiff p-adj   lower   upper  reject
# ---------------------------------------------------------------
#     College  High School  -0.4635 0.0001 -0.7268 -0.2002   True
#     College Postgraduate   0.6142    0.0  0.2856  0.9429   True
# High School Postgraduate   1.0778    0.0  0.7754  1.3801   True
# ---------------------------------------------------------------

# %%
niveles = {'College': 0, 'High School': 50, 'Postgraduate': 100}
df['Parental_Education_Level'] = df['Parental_Education_Level'].map(niveles)
df
#
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                  100
# 1                19          64                     0                   50
# 2                24          98                    50                   50
# 3                29          89                     0                   50
# 4                19          92                    50                   50
# ...             ...         ...                   ...                  ...
# 6602             25          69                   100                   50
# 6603             23          76                   100                   50
# 6604             20          90                    50                    0
# 6605             10          86                   100                  100
# 6606             15          67                    50                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                              0            7               73
# 1                              0            8               59
# 2                              1            7               91
# 3                              1            8               98
# 4                              1            6               65
# ...                          ...          ...              ...
# 6602                           0            7               76
# 6603                           0            8               81
# 6604                           1            6               65
# 6605                           1            6               91
# 6606                           1            9               94
#
#       Motivation_Level  Internet_Access  Tutoring_Sessions  Family_Income  \
# 0                    0                1                  0              0
# 1                    0                1                  2             50
# 2                   50                1                  2             50
# 3                   50                1                  1             50
# 4                   50                1                  3             50
# ...                ...              ...                ...            ...
# 6602                50                1                  1            100
# 6603                50                1                  3              0
# 6604                 0                1                  3              0
# 6605               100                1                  2              0
# 6606                50                1                  0             50
#
#       Teacher_Quality  Peer_Influence  Physical_Activity  \
# 0                   0               1                  3
# 1                   0              -1                  4
# 2                   0               0                  4
# 3                   0              -1                  4
# 4                 100               0                  4
# ...               ...             ...                ...
# 6602                0               1                  2
# 6603              100               1                  2
# 6604                0              -1                  2
# 6605                0               1                  3
# 6606                0               1                  4
#
#       Learning_Disabilities  Parental_Education_Level Distance_from_Home  \
# 0                         0                        50               Near
# 1                         0                         0           Moderate
# 2                         0                       100               Near
# 3                         0                        50           Moderate
# 4                         0                         0               Near
# ...                     ...                       ...                ...
# 6602                      0                        50               Near
# 6603                      0                        50               Near
# 6604                      0                       100               Near
# 6605                      0                        50                Far
# 6606                      0                       100               Near
#
#       Gender  Exam_Score
# 0       Male          67
# 1     Female          61
# 2       Male          74
# 3       Male          71
# 4     Female          70
# ...      ...         ...
# 6602  Female          68
# 6603  Female          69
# 6604  Female          68
# 6605  Female          68
# 6606    Male          64
#
# [6378 rows x 19 columns]

# %%
#Prueba ANOVA para Distancia de casa
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols('Exam_Score ~ C(Distance_from_Home)',data = df ).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#H0: No hay diferencia entre grupos.
# Out:
#                            df        sum_sq     mean_sq          F  \
# C(Distance_from_Home)     2.0    758.421410  379.210705  24.936704
# Residual               6375.0  96944.175015   15.206929        NaN
#
#                              PR(>F)
# C(Distance_from_Home)  1.630308e-11
# Residual                        NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt
nivel_de_significancia = 0.05
tukey = pairwise_tukeyhsd(endog = df['Exam_Score'], groups = df['Distance_from_Home'], alpha = nivel_de_significancia)
tukey.plot_simultaneous(ylabel = 'Niveles de medición', xlabel = 'Unidades de la variable')
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.title('')
print(tukey)
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
#  group1   group2  meandiff p-adj lower  upper  reject
# -----------------------------------------------------
#      Far Moderate   0.4882 0.017 0.0705 0.9059   True
#      Far     Near   1.0154   0.0 0.6237  1.407   True
# Moderate     Near   0.5272   0.0 0.2722 0.7822   True
# -----------------------------------------------------

# %%
niveles = {'Far': 0, 'Moderate': 50, 'Near': 100}
df['Distance_from_Home'] = df['Distance_from_Home'].map(niveles)
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     0                  100
# 1                19          64                     0                   50
# 2                24          98                    50                   50
# 3                29          89                     0                   50
# 4                19          92                    50                   50
# ...             ...         ...                   ...                  ...
# 6602             25          69                   100                   50
# 6603             23          76                   100                   50
# 6604             20          90                    50                    0
# 6605             10          86                   100                  100
# 6606             15          67                    50                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                              0            7               73
# 1                              0            8               59
# 2                              1            7               91
# 3                              1            8               98
# 4                              1            6               65
# ...                          ...          ...              ...
# 6602                           0            7               76
# 6603                           0            8               81
# 6604                           1            6               65
# 6605                           1            6               91
# 6606                           1            9               94
#
#       Motivation_Level  Internet_Access  Tutoring_Sessions  Family_Income  \
# 0                    0                1                  0              0
# 1                    0                1                  2             50
# 2                   50                1                  2             50
# 3                   50                1                  1             50
# 4                   50                1                  3             50
# ...                ...              ...                ...            ...
# 6602                50                1                  1            100
# 6603                50                1                  3              0
# 6604                 0                1                  3              0
# 6605               100                1                  2              0
# 6606                50                1                  0             50
#
#       Teacher_Quality  Peer_Influence  Physical_Activity  \
# 0                   0               1                  3
# 1                   0              -1                  4
# 2                   0               0                  4
# 3                   0              -1                  4
# 4                 100               0                  4
# ...               ...             ...                ...
# 6602                0               1                  2
# 6603              100               1                  2
# 6604                0              -1                  2
# 6605                0               1                  3
# 6606                0               1                  4
#
#       Learning_Disabilities  Parental_Education_Level  Distance_from_Home  \
# 0                         0                        50                 100
# 1                         0                         0                  50
# 2                         0                       100                 100
# 3                         0                        50                  50
# 4                         0                         0                 100
# ...                     ...                       ...                 ...
# 6602                      0                        50                 100
# 6603                      0                        50                 100
# 6604                      0                       100                 100
# 6605                      0                        50                   0
# 6606                      0                       100                 100
#
#       Gender  Exam_Score
# 0       Male          67
# 1     Female          61
# 2       Male          74
# 3       Male          71
# 4     Female          70
# ...      ...         ...
# 6602  Female          68
# 6603  Female          69
# 6604  Female          68
# 6605  Female          68
# 6606    Male          64
#
# [6378 rows x 19 columns]

# %%
#Prueba ANOVA para Gender
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo = smf.ols('Exam_Score ~ C(Gender)',data = df ).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#H0: No hay diferencia entre grupos.
# Out:
#                df        sum_sq    mean_sq         F    PR(>F)
# C(Gender)     1.0      2.377044   2.377044  0.155128  0.693696
# Residual   6376.0  97700.219381  15.323121       NaN       NaN

# %%
df.drop(columns = ['Gender'], inplace = True)

# %%
#HISOGRAMA Exam Score
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Exam_Score'], kde=True, color='skyblue')
plt.xlabel('Puntuación de examen')
plt.ylabel('Frecuencia')
plt.title('Distribución de la Puntuación de examen')


plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

matriz_de_correlación = df.corr()
plt.figure(figsize = (15,9))
sns.heatmap(matriz_de_correlación, annot = True, cmap = 'coolwarm', fmt = "0.2f", square= True, cbar_kws = {'shrink': 0.8})
plt.title('Matriz de Correlación')
plt.show()

# %%
'''
Hours_Studied, Distribución normal sin datos atipicos.

Attendance, Distribución uniforme, sin datos atípicos.

Parental_Involvement, Niveles de medición Low, Medium, High. Hay un aumento entre la participación parental y
calificación del alumno.


Access_to_Resources, Niveles de medición Low, Medium, High. Se aprecia un aumento en la calificación, entre más acceso a recursos.


Extracurricular_Activities, Niveles de medición No, Yes.


Sleep_Hours, Sigue una distribución normal. No hay datos atípicos.

Previous_Scores, Distribución uniforme. No hay datos atípicos.


Motivation_Level, Niveles de medición Low, Medium, High. Se aprecia un aumento en la calificación, entre más motivado.


Internet_Access, Niveles de medición Yes, No. Se aprecia un aumento en la calificación, entre más acceso a internet.


Tutoring_Sessions, Distribución mas cercana a la Poisson. No hay datos atípicos.

Family_Income, Niveles de medición Low, Medium, High. Se aprecia un aumento en la calificación, entre más ingreso familiar.



Teacher_Quality, Niveles de medición Low, medium, high, donde low y medium son una misma.

School_Type, Se elimina la columna por que no aporta información.


Peer_Influence, Niveles de medición Negative, Neutral, Positive. Se aprecia un aumento en la calificación, entre más influye el profesor.

Physical_Activity, Distribución normal, sin datos atípicos.

Learning_Disabilities, niveles de medición No, Yes. Hay una menor calificación si hay discapacidades.

Parental_Education_Level, niveles de medición College, High School, Postgraduate. Hay un aumento en la calificación conforme a la educación del padre.

Distance_from_Home,Niveles de medición Far, Moderate, Near. Hay un aumento en la calificación, entre más cerca se vive de la escuela.

Gender, Se elimina la columna por que no aporta información relevante.

Exam_Score, Se puede ver una distribución normal sin presentar datos atípicos significativos.


Según el mapa de calor se aprecian pocas variables que tienen una relación fuerte,
siendo las horas estudiadas y la asistencia las que mejor demuestran una correlación.


'''
# Out:
# '\nHours_Studied, Distribución normal sin datos atipicos.\n\nAttendance, Distribución uniforme, sin datos atípicos.\n\nParental_Involvement, Niveles de medición Low, Medium, High. Hay un aumento entre la participación parental y \ncalificación del alumno.\n\n\nAccess_to_Resources, Niveles de medición Low, Medium, High. Se aprecia un aumento en la calificación, entre más acceso a recursos.\n\n\nExtracurricular_Activities, Niveles de medición No, Yes.\n\n\nSleep_Hours, Sigue una distribución normal. No hay datos atípicos.\n\nPrevious_Scores, Distribución uniforme. No hay datos atípicos.\n\n\nMotivation_Level, Niveles de medición Low, Medium, High. Se aprecia un aumento en la calificación, entre más motivado.\n\n\nInternet_Access, Niveles de medición Yes, No. Se aprecia un aumento en la calificación, entre más acceso a internet.\n\n\nTutoring_Sessions, Distribución mas cercana a la Poisson. No hay datos atípicos.\n\nFamily_Income, Niveles de medición Low, Medium, High. Se aprecia un aumento en la calificación, entre más ingreso familiar.\n\n\n\nTeacher_Quality, Niveles de medición Low, medium, high, donde low y medium son una misma.  \n\nSchool_Type, Se elimina la columna por que no aporta información.\n\n\nPeer_Influence, Niveles de medición Negative, Neutral, Positive. Se aprecia un aumento en la calificación, entre más influye el profesor.\n\nPhysical_Activity, Distribución normal, sin datos atípicos.\n\nLearning_Disabilities, niveles de medición No, Yes. Hay una menor calificación si hay discapacidades.\n\nParental_Education_Level, niveles de medición College, High School, Postgraduate. Hay un aumento en la calificación conforme a la educación del padre.\n\nDistance_from_Home,Niveles de medición Far, Moderate, Near. Hay un aumento en la calificación, entre más cerca se vive de la escuela.\n\nGender, Se elimina la columna por que no aporta información relevante.\n\nExam_Score, Se puede ver una distribución normal sin presentar datos atípicos significativos.\n'
